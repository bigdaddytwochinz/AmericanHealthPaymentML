# %% [markdown]
# # Analyzing the Inpatient Prospective Payment System of the United States
#
# ### This is an attempt for me to work on some random project and even I am trying to see what is stupid
#
# This is my version of exploratory data analysis!

# %%
install.packages("dplyr")
install.packages('tidyverse')
# Out:
# The downloaded binary packages are in
# 	/var/folders/dc/k8m8dkrn6_9cj9y6k3fy2qrr0000gn/T//Rtmpm07vEg/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/dc/k8m8dkrn6_9cj9y6k3fy2qrr0000gn/T//Rtmpm07vEg/downloaded_packages

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data = read_csv("Inpatient_Prospective_Payment_System__IPPS__Provider_Summary_for_the_Top_100_Diagnosis-Related_Groups__DRG__-_FY2011.csv")
# Out:
# Parsed with column specification:
# cols(
#   `DRG Definition` = col_character(),
#   `Provider Id` = col_double(),
#   `Provider Name` = col_character(),
#   `Provider Street Address` = col_character(),
#   `Provider City` = col_character(),
#   `Provider State` = col_character(),
#   `Provider Zip Code` = col_double(),
#   `Hospital Referral Region Description` = col_character(),
#   `Total Discharges` = col_double(),
#   `Average Covered Charges` = col_double(),
#   `Average Total Payments` = col_double(),
#   `Average Medicare Payments` = col_double()
# )

# %%
glimpse(data)

names(data) = make.names(names(data))
head(data)

tidy = data %>%
            group_by(DRG.Definition) %>% 
            summarise(n = n())

(tidy)
# Out:
# Observations: 163,065
# Variables: 12
# $ DRG.Definition                       <chr> "039 - EXTRACRANIAL PROCEDURES W…
# $ Provider.Id                          <dbl> 10001, 10005, 10006, 10011, 1001…
# $ Provider.Name                        <chr> "SOUTHEAST ALABAMA MEDICAL CENTE…
# $ Provider.Street.Address              <chr> "1108 ROSS CLARK CIRCLE", "2505 …
# $ Provider.City                        <chr> "DOTHAN", "BOAZ", "FLORENCE", "B…
# $ Provider.State                       <chr> "AL", "AL", "AL", "AL", "AL", "A…
# $ Provider.Zip.Code                    <dbl> 36301, 35957, 35631, 35235, 3500…
# $ Hospital.Referral.Region.Description <chr> "AL - Dothan", "AL - Birmingham"…
# $ Total.Discharges                     <dbl> 91, 14, 24, 25, 18, 67, 51, 32, …
# $ Average.Covered.Charges              <dbl> 32963.07, 15131.85, 37560.37, 13…
# $ Average.Total.Payments               <dbl> 5777.24, 5787.57, 5434.95, 5417.…
# ...
